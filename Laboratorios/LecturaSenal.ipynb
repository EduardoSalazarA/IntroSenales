# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import re

# Cargar el archivo de señal txt
with open('simu120.txt') as f:
    # Saltar las tres primeras líneas
    for i in range(3):
        f.readline()
    # Leer la frecuencia
    fs = float(f.readline().split()[-1])
    # Leer los valores de la señal
    signal = np.loadtxt(f)

# Crear un vector de tiempo
time = np.arange(0, len(signal)) / fs

# Seleccionar intervalo de tiempo para plotear
start_time = 0   # tiempo inicial en segundos
end_time = 10     # tiempo final en segundos
start_index = int(start_time * fs)
end_index = int(end_time * fs)

# Plotear la señal
plt.plot(time[start_index:end_index], signal[start_index:end_index],'r')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.title('Señal Respiracion Simulada fin Correr')

# Imprimir la frecuencia
print('Frecuencia de muestreo: {} Hz'.format(fs))

plt.show()
# Out:
# Frecuencia de muestreo: 514.0 Hz
